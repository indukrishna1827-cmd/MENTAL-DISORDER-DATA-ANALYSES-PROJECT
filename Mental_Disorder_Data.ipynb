# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-54175d47-6a27-4caf-9b85-a562602008ef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-54175d47-6a27-4caf-9b85-a562602008ef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/mental_disorders_dataset (5).csv")

# %%
df.head()
# Out:
#   Patient Number    Sadness    Euphoric  Exhausted Sleep dissorder Mood Swing  \
# 0     Patiant-01    Usually      Seldom  Sometimes       Sometimes        YES
# 1     Patiant-02    Usually      Seldom    Usually       Sometimes         NO
# 2     Patiant-03  Sometimes  Most-Often  Sometimes       Sometimes        YES
# 3     Patiant-04    Usually      Seldom    Usually      Most-Often        YES
# 4     Patiant-05    Usually     Usually  Sometimes       Sometimes         NO
#
#   Suicidal thoughts Anorxia Authority Respect Try-Explanation  \
# 0              YES       NO                NO             YES
# 1               YES      NO                NO              NO
# 2                NO      NO                NO             YES
# 3               YES     YES                NO             YES
# 4                NO      NO                NO              NO
#
#   Aggressive Response Ignore & Move-On Nervous Break-down Admit Mistakes  \
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
df.shape
# Out:
# (120, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Patient Number       120 non-null    object
#  1   Sadness              120 non-null    object
#  2   Euphoric             120 non-null    object
#  3   Exhausted            120 non-null    object
#  4   Sleep dissorder      120 non-null    object
#  5   Mood Swing           120 non-null    object
#  6   Suicidal thoughts    120 non-null    object
#  7   Anorxia              120 non-null    object
#  8   Authority Respect    120 non-null    object
#  9   Try-Explanation      120 non-null    object
#  10  Aggressive Response  120 non-null    object
#  11  Ignore & Move-On     120 non-null    object
#  12  Nervous Break-down   120 non-null    object
#  13  Admit Mistakes       120 non-null    object
#  14  Overthinking         120 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Patient Number         0
# Sadness                0
# Euphoric               0
# Exhausted              0
# Sleep dissorder        0
# Mood Swing             0
# Suicidal thoughts      0
# Anorxia                0
# Authority Respect      0
# Try-Explanation        0
# Aggressive Response    0
# Ignore & Move-On       0
# Nervous Break-down     0
# Admit Mistakes         0
# Overthinking           0
# Sexual Activity        0
# Concentration          0
# Optimisim              0
# Expert Diagnose        0
# dtype: int64

# %%
df.describe()
# Out:
#        Patient Number  Sadness Euphoric  Exhausted Sleep dissorder Mood Swing  \
# count             120      120      120        120             120        120
# unique            120        4        4          4               4          2
# top        Patiant-01  Usually   Seldom  Sometimes       Sometimes         NO
# freq                1       42       46         38              44         63
#
#        Suicidal thoughts Anorxia Authority Respect Try-Explanation  \
# count                120     120               120             120
# unique                 3       2                 2               2
# top                   NO      NO                NO              NO
# freq                  63      74                73              63
#
#        Aggressive Response Ignore & Move-On Nervous Break-down Admit Mistakes  \
# count                  120              120                120            120
# unique                   2                2                  2              2
# ...

# %%
sns.countplot(x='Expert Diagnose', data=df, palette='viridis')

plt.title("Distribution of Diagnoses")
plt.show()
# Out:
# /tmp/ipython-input-3862789960.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Expert Diagnose', data=df, palette='viridis')

# %%
print("\nSummary Statistics:")
display(df.describe())
# Out:
# Summary Statistics:
#        Patient Number  Sadness Euphoric  Exhausted Sleep dissorder Mood Swing  \
# count             120      120      120        120             120        120
# unique            120        4        4          4               4          2
# top        Patiant-01  Usually   Seldom  Sometimes       Sometimes         NO
# freq                1       42       46         38              44         63
#
#        Suicidal thoughts Anorxia Authority Respect Try-Explanation  \
# count                120     120               120             120
# unique                 3       2                 2               2
# top                   NO      NO                NO              NO
# freq                  63      74                73              63
#
#        Aggressive Response Ignore & Move-On Nervous Break-down Admit Mistakes  \
# count                  120              120                120            120
# ...

# %%
df.columns
# Out:
# Index(['Patient Number', 'Sadness', 'Euphoric', 'Exhausted', 'Sleep dissorder',
#        'Mood Swing', 'Suicidal thoughts', 'Anorxia', 'Authority Respect',
#        'Try-Explanation', 'Aggressive Response', 'Ignore & Move-On',
#        'Nervous Break-down', 'Admit Mistakes', 'Overthinking',
#        'Sexual Activity', 'Concentration', 'Optimisim', 'Expert Diagnose'],
#       dtype='object')

# %%
sns.boxplot(data=df['Sleep dissorder'],orient='h',palette='pastel')
plt.title("Boxplot of Numerical (Outlier Detection)")
plt.show()
# Out:
# /tmp/ipython-input-2257505102.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df['Sleep dissorder'],orient='h',palette='pastel')

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Expert Diagnose', palette='coolwarm')
plt.title('Distribution of Diagnoses')
plt.show()
# Out:
# /tmp/ipython-input-2258742402.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Expert Diagnose', palette='coolwarm')

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Sadness', hue='Expert Diagnose', palette='magma')
plt.title('Sadness Frequency by Diagnosis')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Overthinking', hue='Expert Diagnose', palette='magma')
plt.title('Overthinking Frequency by Diagnosis')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Euphoric', hue='Expert Diagnose', palette='magma')
plt.title('Euphoric Frequency by Diagnosis')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Exhausted', hue='Expert Diagnose', palette='magma')
plt.title('Exhausted Frequency by Diagnosis')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Sleep dissorder', hue='Expert Diagnose', palette='magma')
plt.title('Sleep dissorder Frequency by Diagnosis')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Mood Swing', hue='Expert Diagnose', palette='magma')
plt.title('Mood Swing Frequency by Diagnosis')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Suicidal thoughts', hue='Expert Diagnose', palette='magma')
plt.title('Suicidal thoughts Frequency by Diagnosis')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Anorxia', hue='Expert Diagnose', palette='magma')
plt.title('Anorxia Frequency by Diagnosis')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Authority Respect', hue='Expert Diagnose', palette='magma')
plt.title('Authority Respect Frequency by Diagnosis')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Try-Explanation', hue='Expert Diagnose', palette='magma')
plt.title('Try-Explanation Frequency by Diagnosis')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Aggressive Response', hue='Expert Diagnose', palette='magma')
plt.title('Aggressive Response Frequency by Diagnosis')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Ignore & Move-On', hue='Expert Diagnose', palette='magma')
plt.title('Ignore & Move-On Frequency by Diagnosis')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Nervous Break-down', hue='Expert Diagnose', palette='magma')
plt.title('Nervous Break-down Frequency by Diagnosis')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Admit Mistakes', hue='Expert Diagnose', palette='magma')
plt.title('Admit Mistakes Frequency by Diagnosis')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Sexual Activity', hue='Expert Diagnose', palette='magma')
plt.title('Sexual Activity Frequency by Diagnosis')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Concentration', hue='Expert Diagnose', palette='magma')
plt.title('Concentration Frequency by Diagnosis')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Optimisim', hue='Expert Diagnose', palette='magma')
plt.title('Optimisim Frequency by Diagnosis')
plt.show()
